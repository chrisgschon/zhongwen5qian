# %%
from neo import NeoGraph
from db import Db

import pandas as pd

g = NeoGraph()

db = Db()
eng = db.create_engine()
df = pd.read_sql("""select * from hsk5k""", eng)

# %%
df['len'] = df['characters'].apply(lambda x: len(list(x)))
df['c1'] = df['characters'].apply(lambda x: list(x)[0])
df['c2'] = df['characters'].apply(lambda x: list(x)[1] if len(x) >= 2 else None)
df['p1'] = df['pinyin'].apply(lambda x: x.split(' ')[0])
df['p2'] = df['pinyin'].apply(lambda x: x.split(' ')[1] if ' ' in x else None)
df['english'] = df['english'].apply(lambda x: x.replace("'", "\\'"))

# %%
df
# Out:
#       hsk characters           pinyin  \
# 0       3         阿姨           a1 yi2
# 1       3          啊               a5
# 2       5          唉              ai1
# 3       6         哎哟          ai1 yo1
# 4       6          挨              ai2
# ...   ...        ...              ...
# 4997    6         作息         zuo4 xi1
# 4998    3         作业         zuo4 ye4
# 4999    3         作用       zuo4 yong4
# 5000    6        座右铭  zuo4 you4 ming2
# 5001    4         作者        zuo4 zhe3
#
#                                                 english  len c1    c2    p1  \
# 0     maternal aunt; step-mother; childcare worker; ...    2  阿     姨    a1
# 1     modal particle ending sentence, showing affirm...    1  啊  None    a5
# 2     interjection or grunt of agreement or recognit...    1  唉  None   ai1
# 3       hey; ow; ouch; interjection of pain or surprise    2  哎     哟   ai1
# 4     to suffer from; to endure; to tide over (a dif...    1  挨  None   ai2
# ...                                                 ...  ... ..   ...   ...
# 4997                                      work and rest    2  作     息  zuo4
# 4998  school assignment; homework; work; task; opera...    2  作     业  zuo4
# 4999  to act on; to affect; action; function; activi...    2  作     用  zuo4
# 5000                                       motto; maxim    3  座     右  zuo4
# 5001                        author; writer; CL:個|个[ge4]    2  作     者  zuo4
#
#          p2
# 0       yi2
# 1      None
# 2      None
# 3       yo1
# 4      None
# ...     ...
# 4997    xi1
# 4998    ye4
# 4999  yong4
# 5000   you4
# 5001   zhe3
#
# [5002 rows x 9 columns]

# %%
df[df['p1'] == 'fen1']
# Out:
#       hsk characters       pinyin  \
# 1081    3          分         fen1
# 1082    6         分辨   fen1 bian4
# 1083    5         分别    fen1 bie2
# 1084    5         分布     fen1 bu4
# 1085    6         分寸    fen1 cun5
# 1086    5         纷纷    fen1 fen1
# 1087    6         吩咐     fen1 fu4
# 1088    6         分红   fen1 hong2
# 1089    6         分解    fen1 jie3
# 1090    6         分裂    fen1 lie4
# 1091    6         分泌     fen1 mi4
# 1092    6         分明   fen1 ming2
# 1093    5         分配    fen1 pei4
# 1094    6         分歧     fen1 qi2
# 1095    6         分散    fen1 san4
# 1096    6         分手   fen1 shou3
# 1097    5         分析     fen1 xi1
# 1098    4       …分之…    fen1 zhi1
# 1099    1         分钟  fen1 zhong1
#
#                                                 english  len c1    c2    p1  \
# 1081  to divide; to separate; to allocate; to distin...    1  分  None  fen1
# 1082  to distinguish; to differentiate; to resolve; ...    2  分     辨  fen1
# 1083  to part or leave each other; to distinguish; d...    2  分     别  fen1
# 1084                         distributed; to distribute    2  分     布  fen1
# 1085  propriety; appropriate behavior; proper speech...    2  分     寸  fen1
# 1086  one after another; in succession; one by one; ...    2  纷     纷  fen1
# 1087                   to tell; to instruct; to command    2  吩     咐  fen1
# 1088                          a bonus; to award a bonus    2  分     红  fen1
# 1089            to resolve; to decompose; to break down    2  分     解  fen1
# 1090       to split up; to divide; to break up; fission    2  分     裂  fen1
# 1091                                            secrete    2  分     泌  fen1
# 1092              clearly demarcated; sharply contoured    2  分     明  fen1
# 1093              to distribute; to assign; to allocate    2  分     配  fen1
# 1094     difference (of opinion, position); bifurcation    2  分     歧  fen1
# 1095                      scatter; disperse; distribute    2  分     散  fen1
# 1096                           to split up; to break up    2  分     手  fen1
# 1097                  to analyze; analysis; CL:個|个[ge4]    2  分     析  fen1
# 1098  used for fractions and percentages, e.g. 四分之一 ...    4  …     分  fen1
# 1099                                             minute    2  分     钟  fen1
#
#           p2
# 1081    None
# 1082   bian4
# 1083    bie2
# 1084     bu4
# 1085    cun5
# 1086    fen1
# 1087     fu4
# 1088   hong2
# 1089    jie3
# 1090    lie4
# 1091     mi4
# 1092   ming2
# 1093    pei4
# 1094     qi2
# 1095    san4
# 1096   shou3
# 1097     xi1
# 1098    zhi1
# 1099  zhong1

# %%
df.groupby(['c1','p1']).size().reset_index().sort_values(by = 'c1')['c1'].value_counts().head(50)
# Out:
# 得    3
# 兴    3
# 重    3
# 长    3
# 着    3
# 称    2
# 答    2
# 几    2
# 别    2
# 过    2
# 切    2
# 为    2
# 似    2
# 折    2
# 倒    2
# 大    2
# 薄    2
# 盛    2
# 地    2
# 教    2
# 曲    2
# 北    2
# 挣    2
# 数    2
# 中    2
# 乐    2
# 抢    2
# 要    2
# 还    2
# 振    2
# 更    2
# 便    2
# 恶    2
# 结    2
# 系    2
# 散    2
# 都    2
# 尽    2
# 行    2
# 刹    2
# 划    2
# 埋    2
# 模    2
# 空    2
# 干    2
# 钻    2
# 强    2
# 传    2
# 朝    2
# 亚    2
# Name: c1, dtype: int64

# %%
df[df['c1'] == '着']
# Out:
#       hsk characters        pinyin  \
# 4602    3         着急     zhao2 ji2
# 4603    5         着凉  zhao2 liang2
# 4604    6         着迷     zhao2 mi2
# 4623    2          着          zhe5
# 4891    6         着手   zhuo2 shou3
# 4892    6         着想  zhuo2 xiang3
# 4894    6         着重  zhuo2 zhong4
#
#                                                 english  len c1    c2     p1  \
# 4602                          to worry; to feel anxious    2  着     急  zhao2
# 4603                                         catch cold    2  着     凉  zhao2
# 4604                 to be fascinated; to be captivated    2  着     迷  zhao2
# 4623  particle attached after verb to indicate actio...    1  着  None   zhe5
# 4891  to put one\'s hand to it; to start out on a ta...    2  着     手  zhuo2
# 4892  to give thought (to others); to consider (othe...    2  着     想  zhuo2
# 4894           put emphasis on; to stress; to emphasize    2  着     重  zhuo2
#
#           p2
# 4602     ji2
# 4603  liang2
# 4604     mi2
# 4623    None
# 4891   shou3
# 4892  xiang3
# 4894  zhong4

# %%
helper = []
chars = []
for i, c in df.iterrows():
    for h, p in zip(list(c['characters']), c['pinyin'].split(' ')):
        helper.append(f'{h} : {p}')
        chars.append(h)

# %%
from collections import Counter, OrderedDict

# %%
g.truncate()
# Out:
# ----- Truncating graph -----

# %%
g.add_characters(list(set(chars)))
# Out:
#   1%|▏         | 37/2634 [00:00<00:07, 367.81it/s]
# ----- Adding chars -----
# 100%|██████████| 2634/2634 [00:02<00:00, 1061.44it/s]
# ----- Done -----

# %%
g.create_links(df[df['len'] == 2])
# Out:
#   0%|          | 3/4025 [00:00<02:14, 29.80it/s]
# ----- Linking two character words -----
#  42%|████▏     | 1696/4025 [00:21<00:29, 78.51it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-22ec088d9651> in <module>
# ----> 1 g.create_links(df[df['len'] == 2])
#
# /app/neo.py in create_links(self, df)
#      36             self.g.run(words)
#      37             english = f"MATCH (s1:Character {{strokes:\'{x['c1']}\'}}),(s2:Character {{strokes:\'{x['c2']}\'}}) CREATE (s1)-[:ENGLISH {{ translation: \'{x['english']}\'}}]->(s2)"
# ---> 38             self.g.run(english)
#      39         print("----- Done -----")
#
# /usr/local/lib/python3.6/dist-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     531         :return:
#     532         """
# --> 533         return self.begin(autocommit=True).run(cypher, parameters, **kwparameters)
#     534
#     535     def separate(self, subgraph):
#
# /usr/local/lib/python3.6/dist-packages/py2neo/database.py in run(self, cypher, parameters, **kwparameters)
#     826                                              graph=self.graph,
#     827                                              keys=[],
# --> 828                                              entities=entities))
#     829         except CypherError as error:
#     830             raise GraphError.hydrate({"code": error.code, "message": error.message})
#
# /usr/local/lib/python3.6/dist-packages/py2neo/internal/connectors.py in run(self, statement, parameters, tx, graph, keys, entities)
#     290     def run(self, statement, parameters=None, tx=None, graph=None, keys=None, entities=None):
#     291         if tx is None:
# --> 292             return self._run_1(statement, parameters, graph, keys, entities)
#     293         else:
#     294             return self._run_in_tx(statement, parameters, tx, graph, keys, entities)
#
# /usr/local/lib/python3.6/dist-packages/py2neo/internal/connectors.py in _run_1(self, statement, parameters, graph, keys, entities)
#     253                     on_success=result.update_metadata, on_failure=self._fail, on_summary=result.done)
#     254         cx.send()
# --> 255         cx.fetch()
#     256         return result
#     257
#
# /usr/local/lib/python3.6/dist-packages/neobolt/direct.py in fetch(self)
#     417     def fetch(self):
#     418         try:
# --> 419             return self._fetch()
#     420         except self.error_handler.known_errors as error:
#     421             self.error_handler.handle(error, self.unresolved_address)
#
# /usr/local/lib/python3.6/dist-packages/neobolt/direct.py in _fetch(self)
#     438             return 0, 0
#     439
# --> 440         self._receive()
#     441
#     442         details, summary_signature, summary_metadata = self._unpack()
#
# /usr/local/lib/python3.6/dist-packages/neobolt/direct.py in _receive(self)
#     487             raise self.Error(message)
#     488         elif received == -1:
# --> 489             raise KeyboardInterrupt()
#     490
#     491     def _unpack(self):
#
# KeyboardInterrupt:
